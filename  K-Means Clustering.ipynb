# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('CIA_Country_Facts.csv')

# %%
df.head()
# Out:
#           Country                               Region  Population  \
# 0     Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1         Albania  EASTERN EUROPE                          3581655
# 2         Algeria  NORTHERN AFRICA                        32930091
# 3  American Samoa  OCEANIA                                   57794
# 4         Andorra  WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    float64
#  5   Coastline (coast/area ratio)        227 non-null    float64
#  6   Net migration                       224 non-null    float64
#  7   Infant mortality (per 1000 births)  224 non-null    float64
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    float64
#  10  Phones (per 1000)                   223 non-null    float64
# ...

# %%
df.describe().transpose()
# Out:
#                                     count          mean           std  \
# Population                          227.0  2.874028e+07  1.178913e+08
# Area (sq. mi.)                      227.0  5.982270e+05  1.790282e+06
# Pop. Density (per sq. mi.)          227.0  3.790471e+02  1.660186e+03
# Coastline (coast/area ratio)        227.0  2.116533e+01  7.228686e+01
# Net migration                       224.0  3.812500e-02  4.889269e+00
# Infant mortality (per 1000 births)  224.0  3.550696e+01  3.538990e+01
# GDP ($ per capita)                  226.0  9.689823e+03  1.004914e+04
# Literacy (%)                        209.0  8.283828e+01  1.972217e+01
# Phones (per 1000)                   223.0  2.360614e+02  2.279918e+02
# Arable (%)                          225.0  1.379711e+01  1.304040e+01
# Crops (%)                           225.0  4.564222e+00  8.361470e+00
# Other (%)                           225.0  8.163831e+01  1.614083e+01
# ...

# %%
sns.histplot(data=df, x='Population')
# Out:
# <Axes: xlabel='Population', ylabel='Count'>

# %%
sns.histplot(data=df[df['Population']<500000000],x='Population')
# Out:
# <Axes: xlabel='Population', ylabel='Count'>

# %%
sns.barplot(data=df, x='Region', y='GDP ($ per capita)', estimator=np.mean);
plt.xticks(rotation=90);

# %%
sns.scatterplot(data=df, x='GDP ($ per capita)', y='Phones (per 1000)', hue='Region')
plt.legend(loc=(1,0.5))

# %%
plt.figure(figsize=(10,6), dpi=200)
sns.scatterplot(data=df, x='GDP ($ per capita)', y='Literacy (%)', hue='Region')
plt.legend(loc=(1,0.5))

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.clustermap(df.corr(numeric_only=True))

# %%
df.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
df[df['Agriculture'].isnull()]['Country']
# Out:
# 3            American Samoa
# 4                   Andorra
# 78                Gibraltar
# 80                Greenland
# 83                     Guam
# 134                 Mayotte
# 140              Montserrat
# 144                   Nauru
# 153      N. Mariana Islands
# 171            Saint Helena
# 174    St Pierre & Miquelon
# 177              San Marino
# 208       Turks & Caicos Is
# 221       Wallis and Futuna
# 223          Western Sahara
# Name: Country, dtype: object

# %%
df[df['Agriculture'].isnull()] = df[df['Agriculture'].isnull()].fillna(0)

# %%
df.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          1
# Infant mortality (per 1000 births)     1
# GDP ($ per capita)                     0
# Literacy (%)                          13
# Phones (per 1000)                      2
# Arable (%)                             1
# Crops (%)                              1
# Other (%)                              1
# Climate                               18
# Birthrate                              1
# Deathrate                              2
# Agriculture                            0
# Industry                               1
# Service                                1
# dtype: int64

# %%
df['Climate'] = df['Climate'].fillna(df.groupby('Region')['Climate'].transform('mean'))

# %%
df.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          1
# Infant mortality (per 1000 births)     1
# GDP ($ per capita)                     0
# Literacy (%)                          13
# Phones (per 1000)                      2
# Arable (%)                             1
# Crops (%)                              1
# Other (%)                              1
# Climate                                0
# Birthrate                              1
# Deathrate                              2
# Agriculture                            0
# Industry                               1
# Service                                1
# dtype: int64

# %%
df[df['Literacy (%)'].isnull()]
# Out:
#                   Country                               Region  Population  \
# 25   Bosnia & Herzegovina  EASTERN EUROPE                          4498976
# 66          Faroe Islands  WESTERN EUROPE                            47246
# 74             Gaza Strip  NEAR EAST                               1428757
# 85               Guernsey  WESTERN EUROPE                            65409
# 99            Isle of Man  WESTERN EUROPE                            75441
# 104                Jersey  WESTERN EUROPE                            91084
# 108              Kiribati  OCEANIA                                  105432
# 123             Macedonia  EASTERN EUROPE                          2050554
# 185              Slovakia  EASTERN EUROPE                          5439448
# 187       Solomon Islands  OCEANIA                                  552438
# 209                Tuvalu  OCEANIA                                   11810
# ...

# %%
df['Literacy (%)'] = df['Literacy (%)'].fillna(df.groupby('Region')['Literacy (%)'].transform('mean'))

# %%
df = df.dropna()

# %%
X = df.drop("Country",axis=1)

# %%
X = pd.get_dummies(X)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

# %%
scaled_X
# Out:
# array([[ 0.0133285 ,  0.01855412, -0.20308668, ..., -0.31544015,
#         -0.54772256, -0.36514837],
#        [-0.21730118, -0.32370888, -0.14378531, ..., -0.31544015,
#         -0.54772256, -0.36514837],
#        [ 0.02905136,  0.97784988, -0.22956327, ..., -0.31544015,
#         -0.54772256, -0.36514837],
#        ...,
#        [-0.06726127, -0.04756396, -0.20881553, ..., -0.31544015,
#         -0.54772256, -0.36514837],
#        [-0.15081724,  0.07669798, -0.22840201, ..., -0.31544015,
#          1.82574186, -0.36514837],
#        [-0.14464933, -0.12356132, -0.2160153 , ..., -0.31544015,
#          1.82574186, -0.36514837]])

# %%
from sklearn.cluster import KMeans

# %%
import os
import warnings

os.environ['OMP_NUM_THREADS'] = '1'

# Подавите предупреждения
warnings.filterwarnings('ignore', category=UserWarning)

ssd = []
for k in range(2, 30):
    model = KMeans(
        n_clusters=k,
        n_init='auto',  # Автоматический выбор, начиная с sklearn 1.4+
        random_state=42,
        max_iter=300,
        tol=1e-4
    )
    model.fit(scaled_X)
    ssd.append(model.inertia_)
    print(f"k={k}: SSD={model.inertia_:.2f}")

# Включите предупреждения обратно
warnings.filterwarnings('default')
# Out:
# k=2: SSD=5498.56
# k=3: SSD=5212.88
# k=4: SSD=4858.00
# k=5: SSD=4549.84
# k=6: SSD=4119.61
# k=7: SSD=3848.23
# k=8: SSD=3578.36
# k=9: SSD=3314.17
# k=10: SSD=3057.83
# k=11: SSD=2911.87
# k=12: SSD=2653.21
# k=13: SSD=2494.67
# k=14: SSD=2405.59
# k=15: SSD=2283.80
# k=16: SSD=2241.17
# k=17: SSD=2184.23
# k=18: SSD=2103.30
# k=19: SSD=2057.88
# k=20: SSD=1960.14
# k=21: SSD=1741.16
# k=22: SSD=1702.33
# k=23: SSD=1654.19
# k=24: SSD=1583.68
# k=25: SSD=1552.61
# k=26: SSD=1546.37
# k=27: SSD=1535.98
# k=28: SSD=1483.35
# k=29: SSD=1442.20

# %%
plt.plot(range(2,30),ssd,'o--')
plt.xlabel("K Value")
plt.ylabel(" Sum of Squared Distances")
# Out:
# Text(0, 0.5, ' Sum of Squared Distances')

# %%
pd.Series(ssd).diff().plot(kind='bar')
# Out:
# <Axes: >

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score
import warnings

# Установите переменную окружения
os.environ['OMP_NUM_THREADS'] = '1'

# Подавление предупреждений
warnings.filterwarnings('ignore', category=UserWarning)

def find_optimal_k(scaled_X, max_k=30, min_k=2):
    """
    Находит оптимальное число кластеров используя несколько методов
    """
    k_values = range(min_k, max_k + 1)
    ssd = []
    silhouette_scores = []
    davies_bouldin_scores = []
    
    print("Анализ оптимального числа кластеров...")
    print("-" * 50)
    
    for k in k_values:
        # Создание и обучение модели
        kmeans_params = {'n_clusters': k, 'random_state': 42}
        
        # Определяем n_init в зависимости от версии sklearn
        try:
            model = KMeans(**kmeans_params, n_init='auto')
        except:
            model = KMeans(**kmeans_params, n_init=10)
            
        model.fit(scaled_X)
        
        # Метрики
        ssd.append(model.inertia_)
        labels = model.labels_
        
        # Silhouette score (требует минимум 2 кластера и не все точки в одном кластере)
        if k > 1 and len(np.unique(labels)) > 1:
            silhouette_scores.append(silhouette_score(scaled_X, labels))
            davies_bouldin_scores.append(davies_bouldin_score(scaled_X, labels))
        else:
            silhouette_scores.append(0)
            davies_bouldin_scores.append(float('inf'))
        
        print(f"k={k:2d}: SSD={ssd[-1]:12.2f}, "
              f"Silhouette={silhouette_scores[-1]:.3f}, "
              f"DB={davies_bouldin_scores[-1]:.3f}")
    
    # Нормализация оценок для комбинированного подхода
    normalized_ssd = (ssd - np.min(ssd)) / (np.max(ssd) - np.min(ssd))
    normalized_silhouette = (silhouette_scores - np.min(silhouette_scores)) / \
                           (np.max(silhouette_scores) - np.min(silhouette_scores))
    normalized_db = (davies_bouldin_scores - np.min(davies_bouldin_scores)) / \
                   (np.max(davies_bouldin_scores) - np.min(davies_bouldin_scores))
    
    # Комбинированная оценка (чем меньше, тем лучше)
    combined_score = normalized_ssd - normalized_silhouette + normalized_db
    
    # Визуализация
    fig, axes = plt.subplots(2, 3, figsize=(15, 10))
    
    # Метод локтя
    axes[0, 0].plot(k_values, ssd, 'bo-')
    axes[0, 0].set_xlabel('Число кластеров (k)')
    axes[0, 0].set_ylabel('SSD (Inertia)')
    axes[0, 0].set_title('Метод локтя')
    axes[0, 0].grid(True, alpha=0.3)
    
    # Silhouette score
    axes[0, 1].plot(k_values, silhouette_scores, 'ro-')
    axes[0, 1].set_xlabel('Число кластеров (k)')
    axes[0, 1].set_ylabel('Silhouette Score')
    axes[0, 1].set_title('Silhouette Score (чем выше, тем лучше)')
    axes[0, 1].grid(True, alpha=0.3)
    
    # Davies-Bouldin index
    axes[0, 2].plot(k_values, davies_bouldin_scores, 'go-')
    axes[0, 2].set_xlabel('Число кластеров (k)')
    axes[0, 2].set_ylabel('Davies-Bouldin Index')
    axes[0, 2].set_title('Davies-Bouldin (чем ниже, тем лучше)')
    axes[0, 2].grid(True, alpha=0.3)
    
    # Производная SSD (для определения "локтя")
    ssd_diff = np.diff(ssd)
    axes[1, 0].plot(k_values[1:], ssd_diff, 'mo-')
    axes[1, 0].set_xlabel('Число кластеров (k)')
    axes[1, 0].set_ylabel('ΔSSD')
    axes[1, 0].set_title('Производная SSD')
    axes[1, 0].grid(True, alpha=0.3)
    
    # Комбинированная оценка
    axes[1, 1].plot(k_values, combined_score, 'co-')
    axes[1, 1].set_xlabel('Число кластеров (k)')
    axes[1, 1].set_ylabel('Комбинированная оценка')
    axes[1, 1].set_title('Комбинированная оценка (чем ниже, тем лучше)')
    axes[1, 1].grid(True, alpha=0.3)
    
    # Рекомендации
    axes[1, 2].axis('off')
    
    # Определение оптимального k разными методами
    optimal_k_elbow = k_values[np.argmin(np.diff(ssd, 2)) + 1] if len(ssd) > 2 else k_values[0]
    optimal_k_silhouette = k_values[np.argmax(silhouette_scores)]
    optimal_k_db = k_values[np.argmin(davies_bouldin_scores)]
    optimal_k_combined = k_values[np.argmin(combined_score)]
    
    # Вывод рекомендаций
    recommendations = f"""
    РЕКОМЕНДАЦИИ ПО ОПТИМАЛЬНОМУ ЧИСЛУ КЛАСТЕРОВ:
    {'='*50}
    1. Метод локтя: k = {optimal_k_elbow}
    2. Silhouette Score: k = {optimal_k_silhouette}
    3. Davies-Bouldin: k = {optimal_k_db}
    4. Комбинированный метод: k = {optimal_k_combined}
    {'='*50}
    Среднее рекомендованное значение: k = {int(np.mean([optimal_k_elbow, optimal_k_silhouette, optimal_k_db, optimal_k_combined]))}
    """
    
    axes[1, 2].text(0.1, 0.5, recommendations, 
                   verticalalignment='center',
                   fontsize=10,
                   bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    plt.tight_layout()
    plt.show()
    
    # Возвращаем результаты
    return {
        'k_values': list(k_values),
        'ssd': ssd,
        'silhouette_scores': silhouette_scores,
        'davies_bouldin_scores': davies_bouldin_scores,
        'optimal_k_elbow': optimal_k_elbow,
        'optimal_k_silhouette': optimal_k_silhouette,
        'optimal_k_db': optimal_k_db,
        'optimal_k_combined': optimal_k_combined
    }

# Использование
results = find_optimal_k(scaled_X, max_k=30, min_k=2)

# Включите предупреждения обратно
warnings.filterwarnings('default')
# Out:
# Анализ оптимального числа кластеров...
# --------------------------------------------------
# k= 2: SSD=     5498.56, Silhouette=0.151, DB=1.910
# k= 3: SSD=     5212.88, Silhouette=0.169, DB=1.749
# k= 4: SSD=     4858.00, Silhouette=0.188, DB=1.849
# k= 5: SSD=     4549.84, Silhouette=0.208, DB=1.802
# k= 6: SSD=     4119.61, Silhouette=0.230, DB=1.684
# k= 7: SSD=     3848.23, Silhouette=0.253, DB=1.621
# k= 8: SSD=     3578.36, Silhouette=0.261, DB=1.606
# k= 9: SSD=     3314.17, Silhouette=0.271, DB=1.520
# k=10: SSD=     3057.83, Silhouette=0.298, DB=1.314
# k=11: SSD=     2911.87, Silhouette=0.307, DB=1.308
# k=12: SSD=     2653.21, Silhouette=0.321, DB=1.240
# k=13: SSD=     2494.67, Silhouette=0.327, DB=1.122
# k=14: SSD=     2405.59, Silhouette=0.288, DB=1.199
# k=15: SSD=     2283.80, Silhouette=0.291, DB=1.125
# k=16: SSD=     2241.17, Silhouette=0.289, DB=1.109
# k=17: SSD=     2184.23, Silhouette=0.236, DB=1.216
# k=18: SSD=     2103.30, Silhouette=0.239, DB=1.206
# ...

# %%
model = KMeans(n_clusters=5)
model.fit(scaled_X)
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=5)

# %%
model.labels_
# Out:
# array([0, 2, 4, 1, 2, 0, 1, 1, 1, 3, 1, 1, 2, 3, 1, 1, 3, 1, 3, 2, 1, 0,
#        2, 3, 1, 2, 0, 1, 1, 3, 2, 0, 3, 0, 3, 0, 2, 1, 2, 0, 0, 1, 3, 1,
#        0, 0, 0, 1, 0, 2, 1, 2, 2, 0, 1, 1, 1, 4, 1, 0, 0, 2, 0, 2, 1, 2,
#        2, 1, 1, 0, 0, 1, 3, 2, 0, 1, 2, 1, 1, 1, 1, 1, 0, 0, 1, 1, 1, 2,
#        2, 2, 3, 3, 3, 1, 2, 2, 1, 2, 1, 2, 2, 1, 3, 0, 1, 3, 2, 1, 3, 3,
#        2, 1, 0, 0, 4, 2, 2, 2, 2, 2, 0, 0, 3, 3, 0, 2, 1, 1, 0, 1, 0, 1,
#        1, 3, 3, 1, 4, 0, 0, 1, 3, 2, 1, 1, 1, 1, 0, 0, 1, 2, 1, 3, 1, 1,
#        1, 1, 1, 3, 2, 2, 1, 1, 1, 2, 3, 0, 1, 1, 1, 1, 1, 1, 2, 1, 1, 0,
#        1, 0, 2, 2, 2, 1, 0, 0, 2, 3, 0, 1, 0, 2, 2, 1, 2, 3, 0, 3, 0, 1,
#        1, 4, 1, 3, 1, 1, 0, 3, 1, 2, 2, 1, 3, 1, 1, 3, 1, 1, 1, 4, 1, 0,
#        0], dtype=int32)

# %%
X['K=5 Clusters'] = model.labels_

# %%
X.corr()['K=5 Clusters'].sort_values()
# Out:
# Region_SUB-SAHARAN AFRICA                    -0.660015
# Birthrate                                    -0.551865
# Infant mortality (per 1000 births)           -0.411618
# Deathrate                                    -0.395941
# Agriculture                                  -0.239824
# Region_LATIN AMER. & CARIB                   -0.174284
# Region_OCEANIA                               -0.115391
# Region_NEAR EAST                             -0.098711
# Other (%)                                    -0.097833
# Crops (%)                                    -0.065666
# Coastline (coast/area ratio)                 -0.028987
# Net migration                                 0.023643
# Region_NORTHERN AMERICA                       0.031167
# Region_BALTICS                                0.068660
# Pop. Density (per sq. mi.)                    0.068883
# Service                                       0.128166
# Area (sq. mi.)                                0.128582
# ...

# %%
print("====================================")
print("Географическая интерпретация модели")
print("====================================")
# Out:
# ...
# Географическая интерпретация модели
# ...

# %%
model = KMeans(n_clusters=15)
    
model.fit(scaled_X)
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=15)

# %%
model = KMeans(n_clusters=5)
    
model.fit(scaled_X)
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=5)

# %%
iso_codes = pd.read_csv("country_iso_codes.csv")

# %%
iso_codes
# Out:
#                                              Country  \
# 0                                        Afghanistan
# 1    Akrotiri and Dhekelia – See United Kingdom, The
# 2                                      Åland Islands
# 3                                            Albania
# 4                                            Algeria
# ..                                               ...
# 296                                 Congo, Dem. Rep.
# 297                             Congo, Repub. of the
# 298                                         Tanzania
# 299                             Central African Rep.
# 300                                    Cote d'Ivoire
#
#                                             ISO Code
# 0                                                AFG
# 1    Akrotiri and Dhekelia – See United Kingdom, The
# 2                                                ALA
# 3                                                ALB
# 4                                                DZA
# ...

# %%
iso_mapping = iso_codes.set_index('Country')['ISO Code'].to_dict()

# %%
iso_mapping
# Out:
# {'Afghanistan': 'AFG',
#  'Akrotiri and Dhekelia – See United Kingdom, The': 'Akrotiri and Dhekelia – See United Kingdom, The',
#  'Åland Islands': 'ALA',
#  'Albania': 'ALB',
#  'Algeria': 'DZA',
#  'American Samoa': 'ASM',
#  'Andorra': 'AND',
#  'Angola': 'AGO',
#  'Anguilla': 'AIA',
#  'Antarctica\u200a[a]': 'ATA',
#  'Antigua and Barbuda': 'ATG',
#  'Argentina': 'ARG',
#  'Armenia': 'ARM',
#  'Aruba': 'ABW',
#  'Ashmore and Cartier Islands – See Australia.': 'Ashmore and Cartier Islands – See Australia.',
#  'Australia\u200a[b]': 'AUS',
#  'Austria': 'AUT',
#  'Azerbaijan': 'AZE',
#  'Bahamas (the)': 'BHS',
#  'Bahrain': 'BHR',
#  'Bangladesh': 'BGD',
#  'Barbados': 'BRB',
#  'Belarus': 'BLR',
#  'Belgium': 'BEL',
#  'Belize': 'BLZ',
#  'Benin': 'BEN',
#  'Bermuda': 'BMU',
#  'Bhutan': 'BTN',
#  'Bolivia (Plurinational State of)': 'BOL',
#  'Bonaire\xa0Sint Eustatius\xa0Saba': 'BES',
#  'Bosnia and Herzegovina': 'BIH',
#  'Botswana': 'BWA',
#  'Bouvet Island': 'BVT',
# ...

# %%
def create_cluster_map(df, iso_mapping, model_labels):
    """
    Создает карту кластеризации стран с обработкой ошибок
    
    df : pandas.DataFrame
        DataFrame с данными о странах
    iso_mapping : dict
        Словарь сопоставления названий стран с ISO кодами
    model_labels : array-like
        Метки кластеров из модели KMeans
    """
    # Создаем копию для безопасной работы
    df_copy = df.copy()
    
    # Проверяем соответствие размеров
    if len(df_copy) != len(model_labels):
        raise ValueError(f"Размеры не совпадают: df имеет {len(df_copy)} строк, "
                        f"model_labels имеет {len(model_labels)} элементов")
    
    # Добавляем ISO коды
    df_copy['ISO Code'] = df_copy['Country'].map(iso_mapping)
    
    # Проверяем пропущенные коды
    missing_mask = df_copy['ISO Code'].isna()
    if missing_mask.any():
        missing_countries = df_copy.loc[missing_mask, 'Country'].tolist()
        print(f"Предупреждение: Не найдены ISO коды для {len(missing_countries)} стран")
        print("Примеры:", missing_countries[:5])
        # Заполняем пропуски
        df_copy['ISO Code'] = df_copy['ISO Code'].fillna('XX')
    
    # Добавляем кластеры
    df_copy['Cluster'] = model_labels
    
    # Создаем карту
    fig = px.choropleth(
        df_copy,
        locations="ISO Code",
        color="Cluster",
        hover_name="Country",
        hover_data=['Cluster'],
        color_continuous_scale='Turbo',
        title="Кластеризация стран"
    )
    
    # Настройки для лучшего отображения
    fig.update_layout(geo=dict(showframe=False, showcoastlines=True))
    
    return fig, df_copy

# Использование функции
fig, df_with_clusters = create_cluster_map(df, iso_mapping, model.labels_)
fig.show()
# Out:
# Предупреждение: Не найдены ISO коды для 36 стран
# Примеры: ['Antigua & Barbuda', 'Bahamas, The', 'Bosnia & Herzegovina', 'British Virgin Is.', 'Brunei']
